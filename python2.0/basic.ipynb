# %%
print("hello world")
# Out:
# hello world

# %%
print(2-1)
# Out:
# 1

# %%
x= 10;
y=7;
z= 5;
print(x+y/z);


print(id(x),id(y),id(z));
y=5;
print(id(x),id(y),id(z));
# Out:
# 11.4
# 140722767119768 140722767119672 140722767119608
# 140722767119768 140722767119608 140722767119608
